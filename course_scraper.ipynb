# %% [markdown]
# # Oscar course lookup parsing

# %% [markdown]
# ## Usage:
# 1. Do a search that will display all the CS courses you're interested in
# 1. use CTRL + A to highlight everyhing on the resulting page.
# 1. use CTRL + C to copy the highlighted contents to your clipboard
# 1. Open a text editor and use CTRL + V to paste the contents of the search into the text file
# 1. Save the text file as "oscar_raw.txt" anywhere (but note the location)
# 1. Run this notebook

# %% [markdown]
# ### Configure environment and packages

# %%
import os
import csv
import pandas as pd
import lxml
import pprint as pp

# %%
base_path = "/mnt/c/Users/samue/Desktop"
raw_name = 'Look-Up Classes to Add_.html'
file_path = os.path.join(base_path, raw_name)

# %%
with open(file_path, 'r') as f:
    data = pd.read_html(f)

# %%
contents_key = 5
school_key = "Computational Science & Engr"

# %%
table_data = data[contents_key][school_key]

# %%
subj_keys = table_data["Subj"].unique()
print(subj_keys)
# Out:
# ['CSE' 'Computer Science' 'Subj' 'CS' 'Industrial & Systems Engr' 'ISYE'
#  'Public Policy' 'PUBP']

# %%
display([(i, table_data[table_data["Subj"] == i].shape[0]) for i in subj_keys])
# Out:
# [('CSE', 7),
#  ('Computer Science', 1),
#  ('Subj', 3),
#  ('CS', 48),
#  ('Industrial & Systems Engr', 1),
#  ('ISYE', 13),
#  ('Public Policy', 1),
#  ('PUBP', 4)]

# %%
subj_filtered_data = table_data[(table_data["Subj"] == "CSE") | (table_data["Subj"] == "CS") | (table_data["Subj"] == "ISYE") | (table_data["Subj"] == "PUBP")]
print(subj_filtered_data["Sec"].unique())
# Out:
# ['OAN' 'O01' 'OCY' 'OCL' 'O03' 'O08' 'O10' 'O11' 'OAH']

# %%
sec_filtered_data = subj_filtered_data[(subj_filtered_data["Sec"] != "OAN") & (subj_filtered_data["Sec"] != "OCY") & (subj_filtered_data["Sec"] != "OCL") & (subj_filtered_data["Sec"] != "OAH")]

# %%
pp.pp(sec_filtered_data.columns)
# Out:
# Index(['Select', 'CRN', 'Subj', 'Crse', 'Sec', 'Cmp', 'Bas', 'Cred', 'Title',
#        'Days', 'Time', 'Cap', 'Act', 'Rem', 'WL Cap', 'WL Act', 'WL Rem',
#        'Instructor', 'Location', 'Attribute', 'Unnamed: 20_level_1',
#        'Unnamed: 21_level_1', 'Unnamed: 22_level_1'],
#       dtype='object')

# %%
numeric_col_names = ["CRN", "Crse", "Cred", "Cap", "Act", "Rem", "WL Cap", "WL Act", "WL Rem"]
useful_cols = ["CRN", "Subj", "Crse", "Sec", "Cred", "Title", "Cap", "Act", "Rem", "WL Cap", "WL Act", "WL Rem", "Instructor"]

# %%
sec_filtered_data[numeric_col_names] = sec_filtered_data[numeric_col_names].apply(pd.to_numeric)
# Out:
# /home/sam/course_parser/venv/lib/python3.8/site-packages/pandas/core/frame.py:3062: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
display(sec_filtered_data.sort_values(["Subj", "WL Act"])[useful_cols])
# Out:
#       CRN  Subj  Crse  Sec  Cred                                      Title  \
# 25  88509    CS  6291  O01   3.0                     Embedded Software Opt.
# 52  87888    CS  8803  O08   3.0  Special TopicsCompilers-Theory & Practice
# 12  86061    CS  6210  O01   3.0                      Adv Operating Systems
# 22  90336    CS  6265  O01   3.0                        Info Sec Lab Binexp
# 14  89891    CS  6238  O01   3.0                    Secure Computer Systems
# 54  92884    CS  8803  O11   3.0  Special TopicsSystem and Network Defenses
# 24  86065    CS  6290  O01   3.0                   High Perform Comput Arch
# 47  89811    CS  7639  O01   3.0                      Cyber Physical Design
# 19  87164    CS  6262  O01   3.0                           Network Security
# 29  87160    CS  6340  O01   3.0                   Software Analysis & Test
# 11  88508    CS  6200  O01   3.0                       Graduate Intro to OS
# 21  88684    CS  6263  O01   3.0                   Intro Cyber Phys Sys Sec
# 28  86066    CS  6310  O01   3.0                     Software Arch & Design
# 34  86741    CS  6460  O01   3.0                      Educ Tech-Foundations
# 9   86583    CS  6035  O01   3.0                     Intro To Info Security
# 42  87393    CS  6750  O01   3.0                    Human-Computer Interact
# 30  87161    CS  6400  O01   3.0                    DB Sys Concepts& Design
# 17  92880    CS  6260  O01   3.0                       Applied Cryptography
# 44  86068    CS  7637  O01   3.0                         Knowledge-Based AI
# 35  86582    CS  6475  O01   3.0                          Comp. Photography
# 53  92883    CS  8803  O10   3.0      Special TopicsAl, Ethics, and Society
# 49  88004    CS  7642  O03   3.0                     Reinforcement Learning
# 16  86062    CS  6250  O01   3.0                          Computer Networks
# 33  86067    CS  6440  O01   3.0                   Intro Health Informatics
# 46  90091    CS  7638  O01   3.0                    Robotics: AI Techniques
# 38  87162    CS  6601  O01   3.0                    Artificial Intelligence
# 26  86063    CS  6300  O01   3.0                       Software Dev Process
# 36  86733    CS  6476  O01   3.0                            Computer Vision
# 50  87358    CS  7646  O01   3.0                     Mach Learn For Trading
# 37  89890    CS  6515  O01   3.0                   Intro to Grad Algorithms
# 48  86064    CS  7641  O01   3.0                           Machine Learning
# 4   87886   CSE  6250  O01   3.0                            Big Data Health
# 2   87163   CSE  6242  O01   3.0                    Data & Visual Analytics
# 1   92942   CSE  6220  O01   3.0                     High Perform Computing
# 59  90609  ISYE  6402  O01   3.0                       Time Series Analysis
# 66  92903  ISYE  6644  O01   3.0                                 Simulation
# 64  92902  ISYE  6501  O01   3.0                   Intro Analytics Modeling
# 62  90610  ISYE  6420  O01   3.0                        Bayesian Statistics
# 76  90725  PUBP  6725  O01   3.0                     Info Security Policies
#
#     Cap  Act  Rem  WL Cap  WL Act  WL Rem                    Instructor
# 25    0   56    0     999       0     999                 Pande, S. (P)
# 52    0   76    0     999       0     999                 Pande, S. (P)
# 12    0  280    0     999       1     998          Ramachandran, U. (P)
# 22    0   24    0     999       1     998                   Kim, T. (P)
# 14    0   65    0     999       2     997                Ahamad, M. (P)
# 54    0   26    0     999       2     997                   Lee, W. (P)
# 24    0  248    0     999       3     996             Prvulovic, M. (P)
# 47    0  107    0     999       3     996                 Feron, E. (P)
# 19    0  175    0     999       5     994                   Lee, W. (P)
# 29    0  176    0     999       7     992        Naik, M. (P), Poch, C.
# 11    0  476    0     999       8     991           Gavrilovska, A. (P)
# 21    0  174    0     999       8     991                 Beyah, R. (P)
# 28    0  430    0     999       9     990                  Moss, M. (P)
# 34    0  216    0     999       9     990                Joyner, D. (P)
# 9     0  333    0     999      10     989                   Lee, W. (P)
# 42    0  365    0     999      10     989                Joyner, D. (P)
# 30    0  288    0     999      12     987                  Mark, L. (P)
# 17    0   50    0     100      42      58             Boldyreva, A. (P)
# 44    0  387    0     999      70     929                Joyner, D. (P)
# 35    0  294    0     999      72     927                  Essa, I. (P)
# 53    0   98    0     999      72     927                Howard, A. (P)
# 49    0  394    0     999      80     919                Isbell, C. (P)
# 16    0  485    0     999     101     898                 Konte, M. (P)
# 33    0  195    0     999     217     782                  Duke, J. (P)
# 46    0  292    0     999     221     778                Summet, J. (P)
# 38    0  389    0     999     516     483                Ploetz, T. (P)
# 26    0  391    0     999     533     466                  Orso, A. (P)
# 36    0  297    0     999     779     220                  Essa, I. (P)
# 50    0  495    0     999     864     135                Joyner, D. (P)
# 37    0  288    0     999     998       1                 Brito, G. (P)
# 48    0  489    0     999     999       0                Isbell, C. (P)
# 4     0  290    0     999      17     982                   Sun, J. (P)
# 2     0  392    0     999     174     825  Chau, D. (P), Roozbahani, M.
# 1     0   57    0     999     254     745     Vuduc, R. (P), Becker, A.
# 59  200   48  152      50       0      50                Serban, N. (P)
# 66  200  121   79      50       0      50              Goldsman, D. (P)
# 64    0  192    0      50      11      39                 Sokol, J. (P)
# 62    0  197    0      50      50       0                Joseph, R. (P)
# 76   50   50    0       0       0       0               Kuerbis, B. (P)
